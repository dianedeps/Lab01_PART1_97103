# %% [markdown]
# ### 03. Data Quality - Profiling
#
# Profiling ingested data with an exploratory/descriptive analysis

# %%
# Parameters
input_path = "data/raw/Acidentes_DadosAbertos_20230613.parquet"
file_type = "parquet"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
